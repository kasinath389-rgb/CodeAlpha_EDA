# %% [markdown]
# # CodeAlpha Data Analytics Internship
# ## Task 2: Exploratory Dta Analysis (EDA)
# ### Project: Analysis of Restuarant Tips Dataset
# **Objectives**
# To analyze the restuarant dataset, identify patterns, visualize the data and draw meaningful coclusions.

# %%
import pandas as pd
import matplotlib.pyplot as plt
print ("Everything is ready!")
# Out:
# Everything is ready!

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
data = pd.read_csv(url)
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data.shape
# Out:
# (244, 7)

# %%
data.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
data["day"].value_counts().plot(kind="bar")
plt.title("Number of Customers by Day")
plt.xlabel("Day")
plt.ylabel("Number of Customers")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.scatter(data["total_bill"], data ["tip"])
plt.title("Total Bill vs Tip")
plt.xlabel("Total Bill")
plt.ylabel("tip")
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
data["day"].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
data["total_bill"].mean()
# Out:
# np.float64(19.78594262295082)

# %% [markdown]
# ## Conclusion
# 1. The dataset contains 244 records and 7 columns.
# 2. No missing values were found.
# 3. The dataset  contains both numerical and categorial variables.
# 4.Saturday had the highest number of customers.
# 5.Customers with higher total bills generally gave higher tips.
# 6. The average total bill and averagge tipwere successfully calculated.
# 7. The dataset was successfully analyzed using Python, Pandas and Matplotlib.
